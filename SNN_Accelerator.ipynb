# %% [markdown]
# <a href="https://colab.research.google.com/github/Umer52-tech/Spiking-Neural-Net-Accelerator/blob/main/SNN_Accelerator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !$ pip install snntorch

import snntorch as snn
from snntorch import spikeplot as splt
from snntorch import spikegen

import torch
import torch.nn as nn

import numpy as np
import matplotlib.pyplot as plt
